# %%
import pandas as pd

# %%
#./hypppo1.py ../data/2012/t-postproc/6.2.csv -e ../data/2012/e-postproc/6.2.csv -o out1b.csv -v2 -s2 -p1 -k9 -D8
out_file = "t.csv_e-e.csv_i-2_s-0_v-5__m-HYPPO_k-15_D-5_L-0.0_p-1.csv"
df = pd.read_csv(out_file, header=None)
print([max(df[col]) for col in df.columns])
M = int(max(df[df.columns[3]])) + 1
# Out:
# [-109.27916694960899, 42.587499470031794, 1.7454781969832383, 5.0, 0.056257194465042, 0.115541229262704, 2574576.672374312, 153.4456387042711, 149.30363206816358, 148.23254840089467]

# %%
dfi = df[df.columns[4:]].transpose()
dfi.reset_index(inplace=True, drop=True)
dfi
# Out:
#         0         1         2         3         4           5         6    \
# 0  0.052021  0.053326  0.052021  0.052021  0.052198    0.052198  0.038820
# 1  0.028541  0.020477  0.028541  0.028541  0.026666    0.026666  0.053449
# 2  0.124498  0.859038  0.285909  0.053168  1.326210  434.480794  2.639638
# 3  0.061436  0.128579  0.061436  0.061436  0.128350    0.128350  1.720848
# 4  0.061651  0.127479  0.061651  0.061651  0.128278    0.128278  1.712778
# 5  0.061935  0.126614  0.061935  0.061935  0.128384    0.128384  1.713179
#
#         7         8          9      ...            682          683       684  \
# 0  0.041406  0.051065   0.052198    ...       0.018611     0.020308  0.013838
# 1  0.032495  0.029505   0.026666    ...       0.017182     0.008034  0.014724
# 2  0.441050  0.655316  15.978942    ...     185.175982  1757.690146  4.622412
# 3  0.033682  0.016529   0.128350    ...       1.253989     0.040652  0.257844
# ...

# %%
plots = [dfi.plot(logy=True, figsize=(6,9), xticks=[0,1,2,3,4])]
[p.set_ylim(top=10**4, bottom=10**(-3)) for p in plots]
[p.set_xlim(left=0, right=4) for p in plots]
[p.get_legend().remove() for p in plots]
figs = [pl.get_figure() for pl in plots]

# %%
out_file = "o.csv"#t.csv_e-e.csv_i-2_s-0_v-5__m-HYPPO_k-15_D-4_L-0.1_p-1.csv"
df = pd.read_csv(out_file, header=None)
print([max(df[col]) for col in df.columns])
dfi = df[df.columns[4:]].transpose()
dfi.reset_index(inplace=True, drop=True)
dfi
# Out:
# [-109.27916694960899, 42.587499470031794, 0.30278700190607, 3.0, 0.052810811065754006, 0.12194416413658198, 69.07887782488892, 461.61319175622725]
#         0         1         2         3         4         5          6    \
# 0  0.052811  0.052811  0.052811  0.042663  0.052811  0.042910   0.038040
# 1  0.077580  0.077580  0.077580  0.072987  0.077580  0.057319   0.027893
# 2  0.250598  0.250598  0.250598  0.176609  0.250598  0.290675   0.227605
# 3  1.089072  1.089072  1.089072  0.986892  1.089072  1.108524  10.255236
#
#         7         8         9      ...          682       683       684  \
# 0  0.044590  0.052811  0.051692    ...     0.027367  0.030194  0.013838
# 1  0.029810  0.077580  0.028823    ...     0.014894  0.008010  0.010891
# 2  0.072088  0.250598  0.325822    ...     0.096244  0.034129  0.060060
# 3  0.934377  1.089072  0.293828    ...     0.184794  0.013040  0.348853
#
#         685       686       687       688       689       690       691
# ...

# %%
plots = [dfi.plot(logy=True, figsize=(6,9), xticks=[0,1,2,3])]
[p.set_ylim(top=10**1, bottom=10**(-3)) for p in plots]
[p.get_legend().remove() for p in plots]
figs = [pl.get_figure() for pl in plots]

# %%
dfs = []
for out_file in [
    "t.csv_e-e.csv_i-2_s-0_v-5__m-HYPPO_k-15_D-5_L-0.0_p-1.csv",
    "t.csv_e-e.csv_i-2_s-0_v-5__m-HYPPO_k-15_D-4_L-0.1_p-1.csv",
    "t.csv_e-e.csv_i-2_s-0_v-5_F-1_m-HYPPO_k-15_D-4_L-0.05_p-1.csv",
    "t.csv_e-e.csv_i-2_s-0_v-5_F-0.5_m-HYPPO_k-15_D-5_L-0_p-1.csv",
    "t.csv_e-e.csv_i-2_s-0_v-5_F-0.5_m-HYPPO_k-15_D-5_L-0.1_p-1.csv",
                ]:
    df = pd.read_csv(out_file, header=None)
    print([max(df[col]) for col in df.columns])
    dfi = df[df.columns[4:]].transpose()
    dfi.reset_index(inplace=True, drop=True)
    dfs.append(dfi)
#print(dfi)
plots = [dfi.plot(logy=True, figsize=(4,5), xticks=[0,1,2,3,4]) for dfi in dfs]
[p.set_ylim(top=10**0.1, bottom=10**(-2.8)) for p in plots]
[p.get_legend().remove() for p in plots]
figs = [pl.get_figure() for pl in plots]
# Out:
# [-109.27916694960899, 42.587499470031794, 1.7454781969832383, 5.0, 0.056257194465042, 0.115541229262704, 2574576.672374312, 153.4456387042711, 149.30363206816358, 148.23254840089467]
# [-109.27916694960899, 42.587499470031794, 1.7454781969832383, 3.0, 0.056257194465042, 0.11554122925731, 0.34347178278012996, 331.73084789292494, 1960152.393560653]
# [-109.27916694960899, 42.587499470031794, 1.874284718908616, 2.0, 0.056257194465042, 0.11554122925794902, 0.11651972990336301, 183790.36185797126, 224660.9735836526]
# [-109.27916694960899, 42.587499470031794, 1.1862895908916862, 5.0, 0.054846259951675004, 0.16468504579802898, 11302051.221187223, 9.425944600679703, 9.15692063851776, 9.593121335862575]
# [-109.27916694960899, 42.587499470031794, 0.4986840742967779, 5.0, 0.054846259951675004, 0.16468504583972599, 0.893111639987749, 0.615220990480566, 0.06020599410138, 0.7291615854018721]

# %%
dfs = []
for out_file in [f"t.csv_e-e.csv_i-2_s-0_v-5_F-0.5_m-HYPPO_k-15_D-4_L-0.0{L}_p-1.csv" for L in ["5","2","1"]]:
    df = pd.read_csv(out_file, header=None)
    print([max(df[col]) for col in df.columns])
    dfi = df[df.columns[4:]].transpose()
    dfi.reset_index(inplace=True, drop=True)
    dfs.append(dfi)
#print(dfi)
plots = [dfi.plot(logy=True, figsize=(4,5), xticks=[0,1,2,3,4]) for dfi in dfs]
[p.set_ylim(top=10**0.1, bottom=10**(-2.8)) for p in plots]
[p.get_legend().remove() for p in plots]
figs = [pl.get_figure() for pl in plots]
# Out:
# [-109.27916694960899, 42.587499470031794, 0.3591000483337029, 4.0, 0.054846259951675004, 0.16468504584355897, 0.893111639987749, 0.582224463488606, 0.062201417287519996]
# [-109.27916694960899, 42.587499470031794, 0.35228069481988, 4.0, 0.054846259951675004, 0.164685045838991, 0.67152501033115, 0.09522785608998699, 0.22444295419642502]
# [-109.27916694960899, 42.587499470031794, 0.366192828557012, 4.0, 0.054846259951675004, 0.164685045798392, 0.615220990480566, 0.057693772409374, 42.091369776042335]

# %%
dfs = []
for out_file in [f"t.csv_e-e.csv_i-2_s-0_v-6_F-0.25_m-HYPPO_k-15_D-4_L-0.0{L}_p-1.csv" for L in ["8","4","2","1","05"]]:
    df = pd.read_csv(out_file, header=None)
    print([max(df[col]) for col in df.columns])
    dfi = df[df.columns[4:]].transpose()
    dfi.reset_index(inplace=True, drop=True)
    dfs.append(dfi)
#print(dfi)
plots = [dfi.plot(logy=True, figsize=(4,5), xticks=[0,1,2,3,4]) for dfi in dfs]
[p.set_ylim(top=10**0.1, bottom=10**(-2.8)) for p in plots]
[p.get_legend().remove() for p in plots]
figs = [pl.get_figure() for pl in plots]
# Out:
# [-109.27916694960899, 42.587499470031794, 0.443363184935041, 1.0, 0.053839321003002004, 0.364052775388522, 0.8704926316739091, 0.8704926316739091, 0.8704926316739091]
# [-109.27916694960899, 42.587499470031794, 0.443363184935041, 4.0, 0.053839321003002004, 0.36405277551103704, 0.8704926316739091, 0.8704926316739091, 0.7736722995268579]
# [-109.27916694960899, 42.587499470031794, 0.704570495989355, 4.0, 0.053839321003002004, 0.364052775535807, 0.8704926316739091, 0.8704926316739091, 0.651225575662291]
# [-109.27916694960899, 42.587499470031794, 0.443363184935041, 4.0, 0.053839321003002004, 0.36405277551581605, 0.8704926316739091, 0.6883009477643779, 0.48760855879052706]
# [-109.27916694960899, 42.587499470031794, 0.713800404349268, 4.0, 0.053839321003002004, 0.364052775383133, 0.7317567968636371, 0.57541741063309, 0.290407847106581]

# %%
#for F in 0 .75 .5 .25; do ./hypppo4.py t.csv -e e.csv -v 6 -k 15 -D 4 -p 1 -L .02 -F $F; done
dfs = []
for out_file in [f"t.csv_e-e.csv_i-2_s-0_v-6_F-{F}_m-HYPPO_k-15_D-4_L-0.02_p-1.csv" for F in ["0.25", "0.5", "0.75", "1"]]:
    df = pd.read_csv(out_file, header=None)
    print([max(df[col]) for col in df.columns])
    dfi = df[df.columns[4:]].transpose()
    dfi.reset_index(inplace=True, drop=True)
    dfs.append(dfi)
#print(dfi)
plots = [dfi.plot(logy=True, figsize=(4,5), xticks=[0,1,2,3,4]) for dfi in dfs]
[p.set_ylim(top=10**0.1, bottom=10**(-2.8)) for p in plots]
[p.get_legend().remove() for p in plots]
figs = [pl.get_figure() for pl in plots]
# Out:
# [-109.27916694960899, 42.587499470031794, 0.704570495989355, 4.0, 0.053839321003002004, 0.364052775535807, 0.8704926316739091, 0.8704926316739091, 0.651225575662291]
# [-109.27916694960899, 42.587499470031794, 0.3594569882528921, 4.0, 0.057634926471734, 0.458117580311524, 0.6466975379356421, 0.048883896932432, 0.384677955081942]
# [-109.27916694960899, 42.587499470031794, 1.0873045465461229, 4.0, 0.057634926471734, 0.213050362301077, 0.106964704928336, 0.9720253106298851, 18707.891787887682]
# [-109.27916694960899, 42.587499470031794, 2.83742485064504, 3.0, 0.068141383451063, 0.367353142082708, 0.24851846011104398, 194887.52935281573, 529885.3212186932]

# %%
#for F in 0 .8 .6 .4 .2; do ./hypppo4.py t.csv -e e.csv -v 5 -k 15 -D 4 -p 1 -L .01 -F $F; done
dfs = []
for out_file in [f"t.csv_e-e.csv_i-2_s-0_v-5_F-{F}_m-HYPPO_k-15_D-4_L-0.01_p-1.csv" for F in ["0.2", "0.4", "0.6", "0.8", "1"]]:
    df = pd.read_csv(out_file, header=None)
    print([max(df[col]) for col in df.columns])
    dfi = df[df.columns[4:]].transpose()
    dfi.reset_index(inplace=True, drop=True)
    dfs.append(dfi)
#print(dfi)
plots = [dfi.plot(logy=True, figsize=(4,5), xticks=[0,1,2,3,4]) for dfi in dfs]
[p.set_ylim(top=10**0.1, bottom=10**(-2.8)) for p in plots]
[p.get_legend().remove() for p in plots]
figs = [pl.get_figure() for pl in plots]
# Out:
# [-109.27916694960899, 42.587499470031794, 1.038355469597882, 4.0, 0.05417122157125, 0.160970976310428, 0.8677907921381031, 0.858147990773175, 0.6883590209193391]
# [-109.27916694960899, 42.587499470031794, 0.35524856968907403, 4.0, 0.052658838478656, 0.165540249596204, 0.730458975702665, 0.394324675568172, 0.19004880836766697]
# [-109.27916694960899, 42.587499470031794, 152.8445162184869, 4.0, 0.052658838478656, 0.146411536147194, 0.47030971238318103, 0.18476861957522697, 1441.3651365424203]
# [-109.27916694960899, 42.587499470031794, 0.33153624865236697, 3.0, 0.052858198269135, 0.13656033433302, 0.060990604849194996, 14.91276325085632, 846634.3937799233]
# [-109.27916694960899, 42.587499470031794, 1.874284718908616, 2.0, 0.056257194465042, 0.11554122926004101, 0.11678353834317699, 138757.8128313165, 1278991.3112876585]

# %%
#for F in 0 .8 .6 .4 .2; do ./hypppo5.py t.csv -e e5.csv -v 5 -k 15 -D 4 -p 1 -F $F; done
dfs = []
for out_file in [f"t.csv_e-e5.csv_i-2_s-0_v-5_F-{F}_m-HYPPO_k-15_D-4_L-1_p-1.csv" for F in ["0.2", "0.4", "0.6", "0.8", "1"]]:
    df = pd.read_csv(out_file, header=None)
    print([max(df[col]) for col in df.columns])
    dfi = df[df.columns[4:]].transpose()
    dfi.reset_index(inplace=True, drop=True)
    dfs.append(dfi)
#print(dfi)
plots = [dfi.plot(logy=True, figsize=(4,5), xticks=[0,1,2,3,4]) for dfi in dfs]
[p.set_ylim(top=10**0.1, bottom=10**(-2.8)) for p in plots]
[p.get_legend().remove() for p in plots]
figs = [pl.get_figure() for pl in plots]
# Out:
# [-109.27916694960899, 42.587499470031794, 5.272127178845073, 1.0, 0.05417122157125, 0.160970976457222, 805145.6383494474, 1499999999985.0, 1499999999985.0]
# [-109.27916694960899, 42.587499470031794, 2.744768858021412, 1.0, 0.052658838478656, 0.16554024965483, 71692.71262444013, 799999999992.254, 325177.49447687867]
# [-109.27916694960899, 42.587499470031794, 0.337970199802675, 1.0, 0.052658838478656, 0.146411536138324, 9070312.023155514, 16644.532634145457, 49303.48799700239]
# [-109.27916694960899, 42.587499470031794, 1.4087599294233781, 1.0, 0.052858198269135, 0.13656033433342402, 4395088.705649581, 411331.44191502186, 163231.6144546437]
# [-109.27916694960899, 42.587499470031794, 1.7454781969832383, 1.0, 0.056257194465042, 0.11554122926051599, 13930097.26652876, 138895.8497957858, 138573.28935808144]

# %%
#for L in .081 .054 .036 .024 .016 .011; do ./hypppo5.py t.csv -e e5.csv -v 5 -k 15 -D 4 -p 1 -L $L; done
dfs = []
for out_file in [f"t.csv_e-e5.csv_i-2_s-0_v-5_F-1_m-HYPPO_k-15_D-4_L-0{L}_p-1.csv" for L in [".081",".054",".036",".024",".016",".011"]]:
    df = pd.read_csv(out_file, header=None)
    print([max(df[col]) for col in df.columns])
    dfi = df[df.columns[4:]].transpose()
    dfi.reset_index(inplace=True, drop=True)
    dfs.append(dfi)
#print(dfi)
plots = [dfi.plot(logy=True, figsize=(4,5), xticks=[0,1,2,3,4]) for dfi in dfs]
[p.set_ylim(top=10**0.1, bottom=10**(-2.8)) for p in plots]
[p.get_legend().remove() for p in plots]
figs = [pl.get_figure() for pl in plots]
# Out:
# [-109.27916694960899, 42.587499470031794, 1.7454781969832383, 2.0, 0.056257194465042, 0.11554122925980902, 5801700.100625781, 1159635.154953641, 141051.5414042037]
# [-109.27916694960899, 42.587499470031794, 1.7454781969832383, 2.0, 0.056257194465042, 0.11554122925996302, 258094811.6725646, 4147367.441622553, 1517048.6090362777]
# [-109.27916694960899, 42.587499470031794, 1.7454781969832383, 1.0, 0.056257194465042, 0.115541229259989, 365663141.5893413, 1152950.6886216584, 228152.67237149636]
# [-109.27916694960899, 42.587499470031794, 1.7454781969832383, 2.0, 0.056257194465042, 0.11554122925833302, 4063729.4419549694, 218435.4657456873, 2212867.42905395]
# [-109.27916694960899, 42.587499470031794, 1.7454781969832383, 1.0, 0.056257194465042, 0.11554122925943801, 31342932.3824327, 253254.8602192144, 140551.360859767]
# [-109.27916694960899, 42.587499470031794, 1.7454781969832383, 2.0, 0.056257194465042, 0.115541229259537, 31269116.19875628, 321531.17590016196, 137568.0308958362]

# %%
#for L in .08 .04 .02 .01; do ./hypppo5.py t.csv -e mini.csv -v 5 -k 15 -D 4 -p 1 -L $L; done
dfs = []
for out_file in [f"t.csv_e-mini.csv_i-2_s-0_v-5_F-1_m-HYPPO_k-15_D-4_L-0.0{L}_p-1.csv" for L in ["8","4","2","1"]]:
    df = pd.read_csv(out_file, header=None)
    print([max(df[col]) for col in df.columns])
    dfi = df[df.columns[4:]].transpose()
    dfi.reset_index(inplace=True, drop=True)
    dfs.append(dfi)
#print(dfi)
plots = [dfi.plot(logy=True, figsize=(4,5), xticks=[0,1,2,3,4]) for dfi in dfs]
[p.set_ylim(top=10**0.1, bottom=10**(-2.8)) for p in plots]
[p.get_legend().remove() for p in plots]
figs = [pl.get_figure() for pl in plots]
# Out:
# [-111.41250027440702, 42.587499470031794, 0.310380394759476, 1.0, 0.05332642338067, 0.053449409175961, 10.183524842291236, 61.611280955435284, 9.007564883938864]
# [-111.41250027440702, 42.587499470031794, 0.310380394759476, 1.0, 0.05332642338067, 0.053449409175424005, 11.138384204645586, 23.67172472418037, 9.007353890572338]
# [-111.41250027440702, 42.587499470031794, 0.310380394759476, 1.0, 0.05332642338067, 0.053449409174300994, 130.1528623230197, 3367.347958649476, 9.007370865101505]
# [-111.41250027440702, 42.587499470031794, 0.310380394759476, 1.0, 0.05332642338067, 0.053449409174774996, 542.2720871660924, 2532.304198110242, 9.007327458558114]

# %%
#for L in .008 .004 .002 .001; do ./hypppo5.py t.csv -e mini.csv -v 5 -k 15 -D 4 -p 0 -L $L; done
dfs = []
for out_file in [f"t.csv_e-mini.csv_i-2_s-0_v-5_F-1_m-HYPPO_k-15_D-4_L-0.00{L}_p-0.csv" for L in ["8","4","2","1"]]:
    df = pd.read_csv(out_file, header=None)
    print([max(df[col]) for col in df.columns])
    dfi = df[df.columns[4:]].transpose()
    dfi.reset_index(inplace=True, drop=True)
    dfs.append(dfi)
#print(dfi)
plots = [dfi.plot(logy=True, figsize=(4,5), xticks=[0,1,2,3,4]) for dfi in dfs]
[p.set_ylim(top=10**0.1, bottom=10**(-2.8)) for p in plots]
[p.get_legend().remove() for p in plots]
figs = [pl.get_figure() for pl in plots]
# Out:
# [-111.41250027440702, 42.587499470031794, 0.310380394759476, 1.0, 0.05332642338067, 0.053449409173906, 704682.2388511292, 15.008126401750555, 9.007493754754515]
# [-111.41250027440702, 42.587499470031794, 0.310380394759476, 2.0, 0.05332642338067, 0.05344940917364, 111.94221134164913, 267.48060643260163, 9.007403365261387]
# [-111.41250027440702, 42.587499470031794, 0.310380394759476, 1.0, 0.05332642338067, 0.053449409174352994, 100.61131077618488, 5489.525060957343, 9.007423405400287]
# [-111.41250027440702, 42.587499470031794, 0.310380394759476, 1.0, 0.05332642338067, 0.053449409177343, 286032.0259680985, 19.99934920457386, 9.007747053909547]

# %%
#for L in .08 .04 .02 .01; do ./hypppo5.py t.csv -e mini.csv -v 4 -k 10 -D 4 -p 0 -L $L; done
dfs = []
for out_file in [f"t.csv_e-mini.csv_i-2_s-0_v-4_F-1_m-HYPPO_k-10_D-4_L-0.0{L}_p-0.csv" for L in ["8","4","2","1"]]:
    df = pd.read_csv(out_file, header=None)
    print([max(df[col]) for col in df.columns])
    dfi = df[df.columns[4:]].transpose()
    dfi.reset_index(inplace=True, drop=True)
    dfs.append(dfi)
#print(dfi)
plots = [dfi.plot(logy=True, figsize=(4,5), xticks=[0,1,2,3,4]) for dfi in dfs]
[p.set_ylim(top=10**0.1, bottom=10**(-2.8)) for p in plots]
[p.get_legend().remove() for p in plots]
figs = [pl.get_figure() for pl in plots]
# Out:
# [-111.41250027440702, 42.587499470031794, 0.28807098762282896, 1.0, 0.037864335474624, 0.057062345807217994, 6.3252024012579104, 113.72323435475272, 54.75295373653038]
# [-111.41250027440702, 42.587499470031794, 0.28807098762282896, 1.0, 0.037864335474624, 0.057062345851555, 6.325212143631189, 68.01873913401262, 2388.2768579451026]
# [-111.41250027440702, 42.587499470031794, 0.28807098762282896, 1.0, 0.037864335474624, 0.057062345852597, 6.325211849062944, 67.84640196924146, 100000000054.06097]
# [-111.41250027440702, 42.587499470031794, 0.28807098762282896, 1.0, 0.037864335474624, 0.057062345894230995, 6.325212502635551, 584476.2966281405, 54.25167110132707]

# %%
#./hypppo5.py t.csv -e mini.csv -v 5 -k 15 -D 5 -p 0 -L 1
dfs = []
for out_file in ["t.csv_e-mini.csv_i-2_s-0_v-5_F-1_m-HYPPO_k-15_D-5_L-1.0_p-0.csv",
                 "t.csv_e-mini.csv_i-2_s-0_v-5_F-1_m-HYPPO_k-15_D-5_L-0.0_p-0.csv",
                 "t.csv_e-e.csv_i-2_s-0_v-5__m-HYPPO_k-15_D-5_L-0.0_p-1.csv"]:
    df = pd.read_csv(out_file, header=None)
    print([max(df[col]) for col in df.columns])
    dfi = df[df.columns[4:]].transpose()
    dfi.reset_index(inplace=True, drop=True)
    dfs.append(dfi)
#print(dfi)
plots = [dfi.plot(logy=True, figsize=(4,5), xticks=[0,1,2,3,4]) for dfi in dfs]
[p.set_ylim(top=10**0.1, bottom=10**(-2.8)) for p in plots]
[p.get_legend().remove() for p in plots]
figs = [pl.get_figure() for pl in plots]
# Out:
# [-111.41250027440702, 42.587499470031794, 0.310380394759476, 1.0, 0.05332642338067, 0.053449409174884, 599999999995.7471, 699999999994.779, 1399999999986.0046, 1499999999985.0]
# [-111.41250027440702, 42.587499470031794, 0.310380394759476, 1.0, 0.05332642338067, 0.053449409178179, 1499999999985.0, 1499999999985.0, 1499999999985.0, 1499999999985.0]
# [-109.27916694960899, 42.587499470031794, 1.7454781969832383, 5.0, 0.056257194465042, 0.115541229262704, 2574576.672374312, 153.4456387042711, 149.30363206816358, 148.23254840089467]

# %%
#for L in .05 .02 .01; do ./hypppo4.py t.csv -e mini.csv -v 5 -k 15 -D 4 -p 0 -L $L; done
dfs = []
for out_file in [f"t.csv_e-mini.csv_i-2_s-0_v-5_F-1_m-HYPPO_k-15_D-4_L-0.0{L}_p-0.csv" for L in ["5","2","1"]]:
    df = pd.read_csv(out_file, header=None)
    print([max(df[col]) for col in df.columns])
    dfi = df[df.columns[4:]].transpose()
    dfi.reset_index(inplace=True, drop=True)
    dfs.append(dfi)
#print(dfi)
plots = [dfi.plot(logy=True, figsize=(4,5), xticks=[0,1,2,3,4]) for dfi in dfs]
[p.set_ylim(top=10**0.1, bottom=10**(-2.8)) for p in plots]
[p.get_legend().remove() for p in plots]
figs = [pl.get_figure() for pl in plots]
# Out:
# [-111.41250027440702, 42.587499470031794, 0.306596878791765, 2.0, 0.05332642338067, 0.053449409173723005, 0.046182279914285, 1.6341264576814858, 431.5063533425448]
# [-111.41250027440702, 42.587499470031794, 0.306596878791765, 2.0, 0.05332642338067, 0.053449409176328, 0.038711951655299, 3.7215100131246297, 148.85211100716637]
# [-111.41250027440702, 42.587499470031794, 0.306596878791765, 2.0, 0.05332642338067, 0.053449409177316, 0.040413147596547, 3.713211817942831, 84.08114219261694]

# %%
by_degree = []
for i in range(M):
    dfi = df[df[3]==i]
    dfi = dfi[dfi.columns[4:]]
    dfi = dfi.transpose()
    dfi.reset_index(inplace=True, drop=True)
    by_degree.append(dfi)
by_degree[3:]
# Out:
# [        8         34        163       193       230       233        270  \
#  0  0.051065  0.043574  0.028295  0.033931  0.033931  0.041818   0.035617
#  1  0.029505  0.029819  0.034838  0.032119  0.032119  0.047421   0.031001
#  2  0.155712  1.033167  1.528313  0.279208  1.896414  0.583583  26.603472
#  3  0.016529  0.003618  0.006358  0.004666  0.004666  0.011682   0.009031
#
#           279        326       428       441       445       469        472
#  0   0.049992   0.025749  0.023606  0.023606  0.023606  0.025176   0.023606
#  1   0.041297   0.035569  0.011054  0.011054  0.011054  0.011589   0.011054
#  2  11.832153  19.925277  1.044520  4.698747  4.994270  2.213875  12.459253
#  3   0.024757   0.010812  0.008875  0.008875  0.008875  0.001625   0.008875  ]

# %%
plots = [bd.plot(logy=True) for bd in by_degree]
[p.set_ylim(top=10**3, bottom=10**(-3)) for p in plots]
[p.get_legend().remove() for p in plots]
figs = [pl.get_figure() for pl in plots]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-878d82ad6e1d> in <module>()
# ----> 1 plots = [bd.plot(logy=True) for bd in by_degree]
#       2 [p.set_ylim(top=10**3, bottom=10**(-3)) for p in plots]
#       3 [p.get_legend().remove() for p in plots]
#       4 figs = [pl.get_figure() for pl in plots]
#
# <ipython-input-3-878d82ad6e1d> in <listcomp>(.0)
# ----> 1 plots = [bd.plot(logy=True) for bd in by_degree]
#       2 [p.set_ylim(top=10**3, bottom=10**(-3)) for p in plots]
#       3 [p.get_legend().remove() for p in plots]
#       4 figs = [pl.get_figure() for pl in plots]
#
# ...

# %%
figs[3]

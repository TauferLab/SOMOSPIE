# %%
import pandas as pd

# %%
regs = pd.read_csv("reg_list.csv", skiprows=[1])

# %%
regs["CEC.lvl1"]=regs["CEC.lvl1"].fillna(-1)

# %%
regs["CEC.lvl1"] = regs["CEC.lvl1"].astype(int)

# %%
regs["CEC.lvl1"]= regs["CEC.lvl1"].astype(str)

# %%
regs["CEC.lvl1"] =  regs["CEC.lvl1"].replace('-1', '')

# %%
# Out:
#     CEC.lvl1  CEC.lvl2 CEC.lvl3                 STATE  \
# 0          1       1.1    1.1.1               Alabama
# 1          2       2.1    1.1.2                Alaska
# 2          3       2.2    2.1.1               Arizona
# 3          4       2.3    2.1.2              Arkansas
# 4          5       2.4    2.1.3            California
# 5          6       3.1    2.1.4              Colorado
# 6          7       3.2    2.1.5           Connecticut
# 7          8       3.3    2.1.6              Delaware
# 8          9       3.4    2.1.7  District of Columbia
# 9         10       4.1    2.1.8               Florida
# 10        11       5.1    2.1.9               Georgia
# 11        12       5.2    2.2.1                Hawaii
# 12        13       5.3    2.2.2                 Idaho
# 13        14       5.4    2.2.3              Illinois
# 14        15       6.1    2.2.4               Indiana
# 15                 6.2    2.2.5                  Iowa
# 16                 7.1    2.2.6                Kansas
# 17                 8.1    2.3.1              Kentucky
# 18                 8.2    2.4.1             Louisiana
# 19                 8.3    2.4.2                 Maine
# 20                 8.4    2.4.3              Maryland
# 21                 8.5    2.4.4         Massachusetts
# 22                 9.2    3.1.1              Michigan
# 23                 9.3    3.1.2             Minnesota
# 24                 9.4    3.1.3           Mississippi
# 25                 9.5    3.2.1              Missouri
# 26                 9.6    3.2.2               Montana
# 27                10.1    3.2.3              Nebraska
# 28                10.2    3.3.1                Nevada
# 29                11.1    3.3.2         New Hampshire
# ..       ...       ...      ...                   ...
# 151                NaN   13.2.1                   NaN
# 152                NaN   13.3.1                   NaN
# 153                NaN   13.4.1                   NaN
# 154                NaN   13.4.2                   NaN
# 155                NaN   13.5.1                   NaN
# 156                NaN   13.5.2                   NaN
# 157                NaN   13.6.1                   NaN
# 158                NaN   13.6.2                   NaN
# 159                NaN   14.1.1                   NaN
# 160                NaN   14.1.2                   NaN
# 161                NaN   14.2.1                   NaN
# 162                NaN   14.3.1                   NaN
# 163                NaN   14.3.2                   NaN
# 164                NaN   14.4.1                   NaN
# 165                NaN   14.4.2                   NaN
# 166                NaN   14.4.3                   NaN
# 167                NaN   14.5.1                   NaN
# 168                NaN   14.5.2                   NaN
# 169                NaN   14.6.1                   NaN
# 170                NaN   14.6.2                   NaN
# 171                NaN   15.1.1                   NaN
# 172                NaN   15.1.2                   NaN
# 173                NaN   15.2.1                   NaN
# 174                NaN   15.2.2                   NaN
# 175                NaN   15.2.3                   NaN
# 176                NaN   15.3.1                   NaN
# 177                NaN   15.4.1                   NaN
# 178                NaN   15.5.1                   NaN
# 179                NaN   15.5.2                   NaN
# 180                NaN   15.6.1                   NaN
#
#                                     NEON                               BOX
# 0      Appalachians / Cumberland Plateau                x1 (longitude min)
# 1                   Atlantic Neotropical                x2 (longitude max)
# 2                         Central Plains                 y1 (latitude min)
# 3                       Desert Southwest                 y2 (latitude max)
# 4                            Great Basin    nx (number of boxes east-west)
# 5                            Great Lakes  ny (number of boxes north-south)
# 6                           Mid Atlantic                               NaN
# 7                              Northeast                               NaN
# 8                        Northern Plains                               NaN
# 9                       Northern Rockies                               NaN
# 10                        Ozarks Complex                               NaN
# 11                     Pacific Northwest                               NaN
# 12                     Pacific Southwest                               NaN
# 13                      Pacific Tropical                               NaN
# 14                     Prairie Peninsula                               NaN
# 15                             Southeast                               NaN
# 16                       Southern Plains                               NaN
# 17   Southern Rockies / Colorado Plateau                               NaN
# 18                                 Taiga                               NaN
# 19                                Tundra                               NaN
# 20                                   NaN                               NaN
# 21                                   NaN                               NaN
# 22                                   NaN                               NaN
# 23                                   NaN                               NaN
# 24                                   NaN                               NaN
# 25                                   NaN                               NaN
# 26                                   NaN                               NaN
# 27                                   NaN                               NaN
# 28                                   NaN                               NaN
# 29                                   NaN                               NaN
# ..                                   ...                               ...
# 151                                  NaN                               NaN
# 152                                  NaN                               NaN
# 153                                  NaN                               NaN
# 154                                  NaN                               NaN
# 155                                  NaN                               NaN
# 156                                  NaN                               NaN
# 157                                  NaN                               NaN
# 158                                  NaN                               NaN
# 159                                  NaN                               NaN
# 160                                  NaN                               NaN
# 161                                  NaN                               NaN
# 162                                  NaN                               NaN
# 163                                  NaN                               NaN
# 164                                  NaN                               NaN
# 165                                  NaN                               NaN
# 166                                  NaN                               NaN
# 167                                  NaN                               NaN
# 168                                  NaN                               NaN
# 169                                  NaN                               NaN
# 170                                  NaN                               NaN
# 171                                  NaN                               NaN
# 172                                  NaN                               NaN
# 173                                  NaN                               NaN
# 174                                  NaN                               NaN
# 175                                  NaN                               NaN
# 176                                  NaN                               NaN
# 177                                  NaN                               NaN
# 178                                  NaN                               NaN
# 179                                  NaN                               NaN
# 180                                  NaN                               NaN
#
# [181 rows x 6 columns]

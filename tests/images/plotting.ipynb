# %%
import argparse, pathlib, re, string 
import pandas as pd 
import matplotlib as mpl
import numpy as np
from matplotlib import pyplot as plt
from os import fspath
from math import ceil
from mpl_toolkits import mplot3d

import numpy as np
import matplotlib.pyplot as plt

# %%
df2016 = pd.read_csv("soil2016.csv", header=0).values

# %%
df2017 = pd.read_csv("soil2017.csv", header=0).values

# %%
fig = plt.figure()
ax = plt.axes(projection="3d")
ax.scatter3D(df2016[:,0], df2016[:,1], df2016[:,2], color='red');
ax.scatter3D(df2017[:,0], df2017[:,1], df2017[:,2], color='blue');
plt.savefig('soil_moisture_comparison.png', dpi = 150)
plt.show()
